# %% [markdown]
# # ETL – Transformation RDF vers CSV (Chicago)
#
# Objectif :
# - Charger les données RDF de Chicago
# - Extraire les informations de ridership
# - Transformer les données en format tabulaire
# - Exporter un CSV propre pour Power BI

# %%
import pandas as pd
import numpy as np
from rdflib import Graph

# %% [markdown]
# Chargement du fichier RDF

# %%
import os
from rdflib import Graph

# Dossier contenant les fichiers RDF
rdf_folder = "../data/raw/chicago/rdf/rdf_CTA__Ridership__Daily_by_Route_routes_2001_2025/"

# Création du graphe global
g = Graph()

file_count = 0

# Chargement de tous les fichiers RDF
for file in os.listdir(rdf_folder):
    if file.endswith(".rdf"):
        file_path = os.path.join(rdf_folder, file)
        g.parse(file_path)
        file_count += 1

print(f"Nombre de fichiers RDF chargés : {file_count}")
print(f"Nombre total de triplets RDF : {len(g)}")
# Out:
# Nombre de fichiers RDF chargés : 19
# Nombre total de triplets RDF : 7647318

# %% [markdown]
# Explorer le contenu RDF

# %%
# Aperçu de quelques triplets RDF
for i, triple in enumerate(g):
    if i == 10:
        break
    print(triple)
# Out:
# (rdflib.term.URIRef('https://data.cityofchicago.org/resource/jyb9-n7fm/row-307896'), rdflib.term.URIRef('https://data.cityofchicago.org/resource/jyb9-n7fm/daytype'), rdflib.term.Literal('W'))
# (rdflib.term.URIRef('https://data.cityofchicago.org/resource/jyb9-n7fm/row-532777'), rdflib.term.URIRef('https://data.cityofchicago.org/resource/jyb9-n7fm/rides'), rdflib.term.Literal('5503', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://data.cityofchicago.org/resource/jyb9-n7fm/row-411218'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('https://data.cityofchicago.org/resource/jyb9-n7fm'))
# (rdflib.term.URIRef('https://data.cityofchicago.org/resource/jyb9-n7fm/row-817393'), rdflib.term.URIRef('http://www.socrata.com/rdf/terms#rowID'), rdflib.term.Literal('row-817393'))
# (rdflib.term.URIRef('https://data.cityofchicago.org/resource/jyb9-n7fm/row-483074'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('https://data.cityofchicago.org/resource/jyb9-n7fm'))
# (rdflib.term.URIRef('https://data.cityofchicago.org/resource/jyb9-n7fm/row-109418'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#member'), rdflib.term.URIRef('https://data.cityofchicago.org/resource/jyb9-n7fm'))
# (rdflib.term.URIRef('https://data.cityofchicago.org/resource/jyb9-n7fm/row-902248'), rdflib.term.URIRef('http://www.socrata.com/rdf/terms#rowID'), rdflib.term.Literal('row-902248'))
# (rdflib.term.URIRef('https://data.cityofchicago.org/resource/jyb9-n7fm/row-919094'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('https://data.cityofchicago.org/resource/jyb9-n7fm'))
# (rdflib.term.URIRef('https://data.cityofchicago.org/resource/jyb9-n7fm/row-1073432'), rdflib.term.URIRef('https://data.cityofchicago.org/resource/jyb9-n7fm/date'), rdflib.term.Literal('2002-09-04T00:00:00'))
# (rdflib.term.URIRef('https://data.cityofchicago.org/resource/jyb9-n7fm/row-168337'), rdflib.term.URIRef('https://data.cityofchicago.org/resource/jyb9-n7fm/route'), rdflib.term.Literal('136'))

# %% [markdown]
# Ajoute cette cellule (exploration ciblée)

# %%
from collections import Counter

predicates = [str(p) for _, p, _ in g]
Counter(predicates).most_common(15)
# Out:
# [('https://data.cityofchicago.org/resource/jyb9-n7fm/daytype', 1092474),
#  ('https://data.cityofchicago.org/resource/jyb9-n7fm/rides', 1092474),
#  ('http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 1092474),
#  ('http://www.socrata.com/rdf/terms#rowID', 1092474),
#  ('http://www.w3.org/2000/01/rdf-schema#member', 1092474),
#  ('https://data.cityofchicago.org/resource/jyb9-n7fm/date', 1092474),
#  ('https://data.cityofchicago.org/resource/jyb9-n7fm/route', 1092474)]

# %% [markdown]
# Extraction RDF → dictionnaire Python

# %%
records = []

for s, p, o in g:
    records.append({
        "subject": str(s),
        "predicate": str(p),
        "object": str(o)
    })

df_rdf = pd.DataFrame(records)
df_rdf.head()
# Out:
#                                              subject  \
# 0  https://data.cityofchicago.org/resource/jyb9-n...
# 1  https://data.cityofchicago.org/resource/jyb9-n...
# 2  https://data.cityofchicago.org/resource/jyb9-n...
# 3  https://data.cityofchicago.org/resource/jyb9-n...
# 4  https://data.cityofchicago.org/resource/jyb9-n...
#
#                                            predicate  \
# 0  https://data.cityofchicago.org/resource/jyb9-n...
# 1  https://data.cityofchicago.org/resource/jyb9-n...
# 2    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 3             http://www.socrata.com/rdf/terms#rowID
# 4    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
#
#                                               object
# 0                                                  W
# 1                                               5503
# 2  https://data.cityofchicago.org/resource/jyb9-n7fm
# 3                                         row-817393
# 4  https://data.cityofchicago.org/resource/jyb9-n7fm

# %% [markdown]
# Filtrer les champs utiles

# %%
df_rdf[df_rdf["predicate"].str.contains("date|route|ride|board", case=False, regex=True)].head(20)
# Out:
#                                               subject  \
# 1   https://data.cityofchicago.org/resource/jyb9-n...
# 8   https://data.cityofchicago.org/resource/jyb9-n...
# 9   https://data.cityofchicago.org/resource/jyb9-n...
# 10  https://data.cityofchicago.org/resource/jyb9-n...
# 23  https://data.cityofchicago.org/resource/jyb9-n...
# 24  https://data.cityofchicago.org/resource/jyb9-n...
# 25  https://data.cityofchicago.org/resource/jyb9-n...
# 26  https://data.cityofchicago.org/resource/jyb9-n...
# 27  https://data.cityofchicago.org/resource/jyb9-n...
# 28  https://data.cityofchicago.org/resource/jyb9-n...
# 30  https://data.cityofchicago.org/resource/jyb9-n...
# 32  https://data.cityofchicago.org/resource/jyb9-n...
# 35  https://data.cityofchicago.org/resource/jyb9-n...
# 37  https://data.cityofchicago.org/resource/jyb9-n...
# 38  https://data.cityofchicago.org/resource/jyb9-n...
# 41  https://data.cityofchicago.org/resource/jyb9-n...
# 43  https://data.cityofchicago.org/resource/jyb9-n...
# 44  https://data.cityofchicago.org/resource/jyb9-n...
# 46  https://data.cityofchicago.org/resource/jyb9-n...
# 47  https://data.cityofchicago.org/resource/jyb9-n...
#
#                                             predicate               object
# 1   https://data.cityofchicago.org/resource/jyb9-n...                 5503
# 8   https://data.cityofchicago.org/resource/jyb9-n...  2002-09-04T00:00:00
# 9   https://data.cityofchicago.org/resource/jyb9-n...                  136
# 10  https://data.cityofchicago.org/resource/jyb9-n...  2021-06-12T00:00:00
# 23  https://data.cityofchicago.org/resource/jyb9-n...                  X49
# 24  https://data.cityofchicago.org/resource/jyb9-n...  2015-03-14T00:00:00
# 25  https://data.cityofchicago.org/resource/jyb9-n...                22927
# 26  https://data.cityofchicago.org/resource/jyb9-n...                   22
# 27  https://data.cityofchicago.org/resource/jyb9-n...                 1205
# 28  https://data.cityofchicago.org/resource/jyb9-n...  2024-04-15T00:00:00
# 30  https://data.cityofchicago.org/resource/jyb9-n...                   84
# 32  https://data.cityofchicago.org/resource/jyb9-n...  2007-09-20T00:00:00
# 35  https://data.cityofchicago.org/resource/jyb9-n...                  136
# 37  https://data.cityofchicago.org/resource/jyb9-n...  2023-02-10T00:00:00
# 38  https://data.cityofchicago.org/resource/jyb9-n...                    2
# 41  https://data.cityofchicago.org/resource/jyb9-n...                 1273
# 43  https://data.cityofchicago.org/resource/jyb9-n...                  151
# 44  https://data.cityofchicago.org/resource/jyb9-n...  2022-06-22T00:00:00
# 46  https://data.cityofchicago.org/resource/jyb9-n...                   53
# 47  https://data.cityofchicago.org/resource/jyb9-n...  2010-02-08T00:00:00

# %% [markdown]
# Conclusion Jusqu'a Ici
#
# “J’ai exploré les prédicats RDF pour identifier les champs métier pertinents avant de les transformer en données tabulaires.”

# %% [markdown]
# Construire le DataFrame final (version simple)

# %%
df_clean = df_rdf[
    df_rdf["predicate"].str.contains("date|route|ride|board", case=False, regex=True)
]

df_clean.head()
# Out:
#                                               subject  \
# 1   https://data.cityofchicago.org/resource/jyb9-n...
# 8   https://data.cityofchicago.org/resource/jyb9-n...
# 9   https://data.cityofchicago.org/resource/jyb9-n...
# 10  https://data.cityofchicago.org/resource/jyb9-n...
# 23  https://data.cityofchicago.org/resource/jyb9-n...
#
#                                             predicate               object
# 1   https://data.cityofchicago.org/resource/jyb9-n...                 5503
# 8   https://data.cityofchicago.org/resource/jyb9-n...  2002-09-04T00:00:00
# 9   https://data.cityofchicago.org/resource/jyb9-n...                  136
# 10  https://data.cityofchicago.org/resource/jyb9-n...  2021-06-12T00:00:00
# 23  https://data.cityofchicago.org/resource/jyb9-n...                  X49

# %% [markdown]
# ## transformer le RDF en table exploitable (CSV).

# %% [markdown]
# Extraire le type d’info depuis predicate

# %%
# Identifier le type d'information
def extract_feature(predicate):
    if "date" in predicate:
        return "date"
    elif "route" in predicate:
        return "route"
    elif "board" in predicate:
        return "boardings"
    elif "ride" in predicate:
        return "rides"
    else:
        return None

df_clean["feature"] = df_clean["predicate"].apply(extract_feature)
df_clean.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4776\2035203407.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["feature"] = df_clean["predicate"].apply(extract_feature)
#                                               subject  \
# 1   https://data.cityofchicago.org/resource/jyb9-n...
# 8   https://data.cityofchicago.org/resource/jyb9-n...
# 9   https://data.cityofchicago.org/resource/jyb9-n...
# 10  https://data.cityofchicago.org/resource/jyb9-n...
# 23  https://data.cityofchicago.org/resource/jyb9-n...
#
#                                             predicate               object  \
# 1   https://data.cityofchicago.org/resource/jyb9-n...                 5503
# 8   https://data.cityofchicago.org/resource/jyb9-n...  2002-09-04T00:00:00
# 9   https://data.cityofchicago.org/resource/jyb9-n...                  136
# 10  https://data.cityofchicago.org/resource/jyb9-n...  2021-06-12T00:00:00
# 23  https://data.cityofchicago.org/resource/jyb9-n...                  X49
#
#    feature
# 1    rides
# 8     date
# 9    route
# 10    date
# 23   route

# %% [markdown]
# Passer de format RDF → format table (pivot)

# %%
df_pivot = (
    df_clean
    .pivot_table(
        index="subject",
        columns="feature",
        values="object",
        aggfunc="first"
    )
    .reset_index()
)

df_pivot.head()
# Out:
# feature                                            subject  \
# 0        https://data.cityofchicago.org/resource/jyb9-n...
# 1        https://data.cityofchicago.org/resource/jyb9-n...
# 2        https://data.cityofchicago.org/resource/jyb9-n...
# 3        https://data.cityofchicago.org/resource/jyb9-n...
# 4        https://data.cityofchicago.org/resource/jyb9-n...
#
# feature                 date rides route
# 0        2001-01-02T00:00:00  5813     1
# 1        2001-01-03T00:00:00  6809     1
# 2        2001-01-16T00:00:00  7775     1
# 3        2001-05-22T00:00:00  7429     1
# 4        2004-12-02T00:00:00  3925     1

# %% [markdown]
# Nettoyage & typage

# %%
df_pivot["date"] = pd.to_datetime(df_pivot["date"], errors="coerce")
df_pivot["rides"] = pd.to_numeric(df_pivot["rides"], errors="coerce")

df_pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1092474 entries, 0 to 1092473
# Data columns (total 4 columns):
#  #   Column   Non-Null Count    Dtype
# ---  ------   --------------    -----
#  0   subject  1092474 non-null  object
#  1   date     1092474 non-null  datetime64[ns]
#  2   rides    1092474 non-null  int64
#  3   route    1092474 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 33.3+ MB

# %%
# Vérification rapide des valeurs
df_pivot.head()
# Out:
# feature                                            subject       date  rides  \
# 0        https://data.cityofchicago.org/resource/jyb9-n... 2001-01-02   5813
# 1        https://data.cityofchicago.org/resource/jyb9-n... 2001-01-03   6809
# 2        https://data.cityofchicago.org/resource/jyb9-n... 2001-01-16   7775
# 3        https://data.cityofchicago.org/resource/jyb9-n... 2001-05-22   7429
# 4        https://data.cityofchicago.org/resource/jyb9-n... 2004-12-02   3925
#
# feature route
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
# Nettoyage des données
df_pivot = df_pivot.dropna(subset=["date", "route", "rides"])

# %% [markdown]
# NOTEBOOK 01 — Export CSV

# %%
output_path = "../data/processed/cta_ridership_by_route_daily.csv"
df_pivot.to_csv(output_path, index=False)

print("CSV exporté :", output_path)
# Out:
# CSV exporté : ../data/processed/cta_ridership_by_route_daily.csv
